# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, UpSampling3D, Add
from tensorflow.keras.models import Model


# Clear tensor sessions to free up memory

tf.keras.backend.clear_session()
# Out:
# 2023-12-05 08:36:24.844352: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
import netCDF4 as nc
from netCDF4 import num2date
import numpy as np

# Load the data for both years
#data_2020 = nc.Dataset('/Users/heyj/Desktop/sql project/2020data.nc')
#data_2021 = nc.Dataset('/Users/heyj/Desktop/sql project/2020data.nc')
data_2020 = nc.Dataset('2020data00UTC.nc') #(choose a specific timestamp: 00UTC for each day)
data_2021 = nc.Dataset('2021data00UTC.nc')

# Combine data from both years
#z_combined = np.concatenate((data_2020['z'][:], data_2021['z'][:]), axis=0)
u_combined = np.concatenate((data_2020['u'][:], data_2021['u'][:]), axis=0)
v_combined = np.concatenate((data_2020['v'][:], data_2021['v'][:]), axis=0)

data_2020.variables
# Out:
# {'longitude': <class 'netCDF4._netCDF4.Variable'>
#  float32 longitude(longitude)
#      units: degrees_east
#      long_name: longitude
#  unlimited dimensions:
#  current shape = (101,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'latitude': <class 'netCDF4._netCDF4.Variable'>
#  float32 latitude(latitude)
#      units: degrees_north
#      long_name: latitude
#  unlimited dimensions:
#  current shape = (81,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'level': <class 'netCDF4._netCDF4.Variable'>
#  int32 level(level)
#      units: millibars
#      long_name: pressure_level
#  unlimited dimensions:
#  current shape = (3,)
#  filling on, default _FillValue of -2147483647 used,
#  'time': <class 'netCDF4._netCDF4.Variable'>
#  int32 time(time)
#      units: hours since 1900-01-01 00:00:00.0
#      long_name: time
#      calendar: gregorian
#  unlimited dimensions:
#  current shape = (365,)
#  filling on, default _FillValue of -2147483647 used,
#  'z': <class 'netCDF4._netCDF4.Variable'>
#  int16 z(time, level, latitude, longitude)
#      scale_factor: 0.40578917539636516
#      add_offset: 18024.8889022873
#      _FillValue: -32767
#      missing_value: -32767
#      units: m**2 s**-2
#      long_name: Geopotential
#      standard_name: geopotential
#  unlimited dimensions:
#  current shape = (365, 3, 81, 101)
#  filling on,
#  'u': <class 'netCDF4._netCDF4.Variable'>
#  int16 u(time, level, latitude, longitude)
#      scale_factor: 0.0012671037397189203
#      add_offset: -1.063484504018297
#      _FillValue: -32767
#      missing_value: -32767
#      units: m s**-1
#      long_name: U component of wind
#      standard_name: eastward_wind
#  unlimited dimensions:
#  current shape = (365, 3, 81, 101)
#  filling on,
#  'v': <class 'netCDF4._netCDF4.Variable'>
#  int16 v(time, level, latitude, longitude)
#      scale_factor: 0.0013600008997733013
#      add_offset: -1.467003852988949
#      _FillValue: -32767
#      missing_value: -32767
#      units: m s**-1
#      long_name: V component of wind
#      standard_name: northward_wind
#  unlimited dimensions:
#  current shape = (365, 3, 81, 101)
#  filling on}

# %%
times_2020 = data_2020['time'][:]
dates_2020 = nc.num2date(times_2020, units=data_2020['time'].units)

times_2021 = data_2021['time'][:]
dates_2021 = nc.num2date(times_2021, units=data_2021['time'].units)

all_dates = np.concatenate((dates_2020, dates_2021))

# %%
# Preprocessing the data

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()

#z_normalized = scaler.fit_transform(z_combined.reshape(-1, 1)).reshape(z_combined.shape)
u_normalized = scaler.fit_transform(u_combined.reshape(-1, 1)).reshape(u_combined.shape)
v_normalized = scaler.fit_transform(v_combined.reshape(-1, 1)).reshape(v_combined.shape)

# Combine the parameters to form a single dataset
#data_combined = np.stack((z_normalized, u_normalized, v_normalized), axis=-1)
data_combined = np.stack((u_normalized, v_normalized), axis=-1)
# Pad the data to get even dimensions
padded_data = np.pad(data_combined, ((0, 0), (0, 1), (0, 1), (0, 1), (0, 0)), mode='constant')
np.info(padded_data)
# Out:
# class:  ndarray
# shape:  (731, 4, 82, 102, 2)
# strides:  (535296, 133824, 1632, 16, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x7f0c2e420010
# byteorder:  little
# byteswap:  False
# type: float64

# %%
# Preprocessing the data

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()

#z_normalized = scaler.fit_transform(z_combined.reshape(-1, 1)).reshape(z_combined.shape)
u_normalized = scaler.fit_transform(u_combined.reshape(-1, 1)).reshape(u_combined.shape)
v_normalized = scaler.fit_transform(v_combined.reshape(-1, 1)).reshape(v_combined.shape)

# Combine the parameters to form a single dataset
#data_combined = np.stack((z_normalized, u_normalized, v_normalized), axis=-1)
data_combined = np.stack((u_normalized, v_normalized), axis=-1)

# Pad the data to get even dimensions
padded_data = np.pad(data_combined, ((0, 0), (0, 1), (0, 1), (0, 1), (0, 0)), mode='constant')


# Split the data into training and validation sets

X_train, X_val, dates_train, dates_val = train_test_split(padded_data, all_dates, test_size=0.3, random_state=42)
#X_train, X_val = train_test_split(padded_data, test_size=0.3, random_state=42)

np.info(padded_data)
# Out:
# class:  ndarray
# shape:  (731, 4, 82, 102, 2)
# strides:  (535296, 133824, 1632, 16, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x7f0bf6537010
# byteorder:  little
# byteswap:  False
# type: float64

# %%
import numpy as np
np.save ('X_train.npy', X_train)
np.save ('dates_train.npy', dates_train)

# %%
print("Training data shape", X_train.shape)
print("Validation data shape", X_val.shape)
# Out:
# Training data shape (511, 4, 82, 102, 2)
# Validation data shape (220, 4, 82, 102, 2)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, UpSampling3D, Add
from tensorflow.keras.models import Model


# Clear tensor sessions to free up memory

tf.keras.backend.clear_session()
# Define ResNet block
def resnet_block(input_tensor, filters, kernel_size=(3, 3, 3), strides=(1, 1, 1)):
    x = Conv3D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    x = Conv3D(filters, kernel_size, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    
    # Adjust the shortcut connection
    if strides != (1, 1, 1) or input_tensor.shape[-1] != filters:
        shortcut = Conv3D(filters, (1, 1, 1), strides=strides, padding='same')(input_tensor)
    else:
        shortcut = input_tensor
    
    x = Add()([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    return x


# Define the model architecture
input_shape_padded = (4, 82, 102, 2)
inputs = Input(shape=input_shape_padded)

# Encoder
x = resnet_block(inputs, 32)
x = resnet_block(x, 64)
encoded = resnet_block(x, 128, strides=(2, 2, 2))

# Decoder
x = UpSampling3D((2, 2, 2))(encoded)
x = resnet_block(x, 64)
x = UpSampling3D((1, 1, 1))(x)
x = resnet_block(x, 32)
decoded = Conv3D(2, (3, 3, 3), activation='sigmoid', padding='same')(x)

# Compile the autoencoder
autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Print the model summary
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4, 82, 102,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 4, 82, 102, 3 1760        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 82, 102, 3 128         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 82, 102, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 4, 82, 102, 3 27680       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, 82, 102, 3 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 4, 82, 102, 3 96          input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 82, 102, 3 0           batch_normalization_1[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4, 82, 102, 3 0           add[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 4, 82, 102, 6 55360       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 82, 102, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, 82, 102, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 4, 82, 102, 6 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 82, 102, 6 256         conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 4, 82, 102, 6 2112        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 82, 102, 6 0           batch_normalization_3[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, 82, 102, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 2, 41, 51, 12 221312      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2, 41, 51, 12 512         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2, 41, 51, 12 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 2, 41, 51, 12 442496      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 41, 51, 12 512         conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 2, 41, 51, 12 8320        activation_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 2, 41, 51, 12 0           batch_normalization_5[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2, 41, 51, 12 0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 4, 82, 102, 1 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 4, 82, 102, 6 221248      up_sampling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 82, 102, 6 256         conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 82, 102, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 4, 82, 102, 6 110656      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 82, 102, 6 256         conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 4, 82, 102, 6 8256        up_sampling3d[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 82, 102, 6 0           batch_normalization_7[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 82, 102, 6 0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 4, 82, 102, 6 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, 82, 102, 3 55328       up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 82, 102, 3 128         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 82, 102, 3 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, 82, 102, 3 27680       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 82, 102, 3 128         conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, 82, 102, 3 2080        up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 82, 102, 3 0           batch_normalization_9[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 82, 102, 3 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, 82, 102, 2 1730        activation_9[0][0]
# ==================================================================================================
# Total params: 1,299,330
# Trainable params: 1,298,050
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
# Train the model 
history = autoencoder.fit(X_train, X_train, epochs=50, batch_size=32, validation_data=(X_val, X_val))
# Out:
# 2023-12-05 08:46:32.177753: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-12-05 08:46:32.196288: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2100000000 Hz
# Epoch 1/50
# 2023-12-05 08:46:35.491106: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-12-05 08:46:36.140816: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8905
# 2023-12-05 08:46:36.819216: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-12-05 08:46:36.819714: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 16/16 [==============================] - 33s 1s/step - loss: 0.0204 - val_loss: 0.0843
# Epoch 2/50
# 16/16 [==============================] - 16s 1s/step - loss: 0.0014 - val_loss: 0.0241
# Epoch 3/50
# 16/16 [==============================] - 17s 1s/step - loss: 7.4543e-04 - val_loss: 0.0103
# Epoch 4/50
# 16/16 [==============================] - 17s 1s/step - loss: 4.9307e-04 - val_loss: 0.0081
# Epoch 5/50
# 16/16 [==============================] - 17s 1s/step - loss: 3.8567e-04 - val_loss: 0.0097
# Epoch 6/50
# 16/16 [==============================] - 18s 1s/step - loss: 3.3761e-04 - val_loss: 0.0108
# Epoch 7/50
# 16/16 [==============================] - 18s 1s/step - loss: 3.1012e-04 - val_loss: 0.0122
# Epoch 8/50
# 16/16 [==============================] - 18s 1s/step - loss: 3.4867e-04 - val_loss: 0.0130
# Epoch 9/50
# 16/16 [==============================] - 19s 1s/step - loss: 2.5103e-04 - val_loss: 0.0152
# Epoch 10/50
# 16/16 [==============================] - 19s 1s/step - loss: 2.5935e-04 - val_loss: 0.0143
# Epoch 11/50
# 16/16 [==============================] - 20s 1s/step - loss: 2.2162e-04 - val_loss: 0.0154
# Epoch 12/50
# 16/16 [==============================] - 19s 1s/step - loss: 2.6753e-04 - val_loss: 0.0149
# Epoch 13/50
# 16/16 [==============================] - 20s 1s/step - loss: 3.3689e-04 - val_loss: 0.0157
# Epoch 14/50
# 16/16 [==============================] - 20s 1s/step - loss: 3.0470e-04 - val_loss: 0.0166
# Epoch 15/50
# 16/16 [==============================] - 22s 1s/step - loss: 3.0946e-04 - val_loss: 0.0162
# Epoch 16/50
# 16/16 [==============================] - 21s 1s/step - loss: 2.0404e-04 - val_loss: 0.0147
# Epoch 17/50
# 16/16 [==============================] - 22s 1s/step - loss: 2.1723e-04 - val_loss: 0.0129
# Epoch 18/50
# 16/16 [==============================] - 23s 1s/step - loss: 2.6445e-04 - val_loss: 0.0124
# Epoch 19/50
# 16/16 [==============================] - 24s 1s/step - loss: 1.8756e-04 - val_loss: 0.0121
# Epoch 20/50
# 16/16 [==============================] - 24s 1s/step - loss: 2.4113e-04 - val_loss: 0.0130
# Epoch 21/50
# 16/16 [==============================] - 24s 1s/step - loss: 3.0365e-04 - val_loss: 0.0118
# Epoch 22/50
# 16/16 [==============================] - 23s 1s/step - loss: 3.1993e-04 - val_loss: 0.0119
# Epoch 23/50
# 16/16 [==============================] - 23s 1s/step - loss: 2.2707e-04 - val_loss: 0.0088
# Epoch 24/50
# 16/16 [==============================] - 25s 2s/step - loss: 1.6907e-04 - val_loss: 0.0086
# Epoch 25/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.4576e-04 - val_loss: 0.0073
# Epoch 26/50
# 16/16 [==============================] - 23s 1s/step - loss: 1.8063e-04 - val_loss: 0.0079
# Epoch 27/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.3078e-04 - val_loss: 0.0058
# Epoch 28/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.4958e-04 - val_loss: 0.0046
# Epoch 29/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.7128e-04 - val_loss: 0.0049
# Epoch 30/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.3536e-04 - val_loss: 0.0041
# Epoch 31/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.3046e-04 - val_loss: 0.0046
# Epoch 32/50
# 16/16 [==============================] - 24s 2s/step - loss: 2.1226e-04 - val_loss: 0.0034
# Epoch 33/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.5265e-04 - val_loss: 0.0024
# Epoch 34/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.1600e-04 - val_loss: 0.0027
# Epoch 35/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.6654e-04 - val_loss: 0.0020
# Epoch 36/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.7322e-04 - val_loss: 0.0018
# Epoch 37/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.3468e-04 - val_loss: 0.0017
# Epoch 38/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.4336e-04 - val_loss: 0.0012
# Epoch 39/50
# 16/16 [==============================] - 24s 2s/step - loss: 9.7140e-05 - val_loss: 8.8635e-04
# Epoch 40/50
# 16/16 [==============================] - 24s 2s/step - loss: 9.4086e-05 - val_loss: 0.0010
# Epoch 41/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.4592e-04 - val_loss: 6.6459e-04
# Epoch 42/50
# 16/16 [==============================] - 24s 2s/step - loss: 1.3172e-04 - val_loss: 5.5661e-04
# Epoch 43/50
# 16/16 [==============================] - 25s 2s/step - loss: 1.1985e-04 - val_loss: 3.4827e-04
# Epoch 44/50
# 16/16 [==============================] - 25s 2s/step - loss: 1.3170e-04 - val_loss: 1.9054e-04
# Epoch 45/50
# 16/16 [==============================] - 25s 2s/step - loss: 1.4618e-04 - val_loss: 2.4408e-04
# Epoch 46/50
# 16/16 [==============================] - 26s 2s/step - loss: 1.0479e-04 - val_loss: 2.1978e-04
# Epoch 47/50
# 16/16 [==============================] - 26s 2s/step - loss: 1.2250e-04 - val_loss: 3.0747e-04
# Epoch 48/50
# 16/16 [==============================] - 26s 2s/step - loss: 1.2231e-04 - val_loss: 1.3979e-04
# Epoch 49/50
# 16/16 [==============================] - 26s 2s/step - loss: 9.1826e-05 - val_loss: 2.4958e-04
# Epoch 50/50
# 16/16 [==============================] - 26s 2s/step - loss: 1.3023e-04 - val_loss: 1.1904e-04

# %%
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 4, 82, 102,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 4, 82, 102, 3 1760        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 4, 82, 102, 3 128         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 82, 102, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 4, 82, 102, 3 27680       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 4, 82, 102, 3 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 4, 82, 102, 3 96          input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4, 82, 102, 3 0           batch_normalization_1[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 4, 82, 102, 3 0           add[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 4, 82, 102, 6 55360       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 4, 82, 102, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 4, 82, 102, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 4, 82, 102, 6 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4, 82, 102, 6 256         conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 4, 82, 102, 6 2112        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 82, 102, 6 0           batch_normalization_3[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, 82, 102, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 2, 41, 51, 12 221312      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 2, 41, 51, 12 512         conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2, 41, 51, 12 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 2, 41, 51, 12 442496      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 41, 51, 12 512         conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 2, 41, 51, 12 8320        activation_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 2, 41, 51, 12 0           batch_normalization_5[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2, 41, 51, 12 0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 4, 82, 102, 1 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 4, 82, 102, 6 221248      up_sampling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 82, 102, 6 256         conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 82, 102, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 4, 82, 102, 6 110656      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 82, 102, 6 256         conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 4, 82, 102, 6 8256        up_sampling3d[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 82, 102, 6 0           batch_normalization_7[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 82, 102, 6 0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 4, 82, 102, 6 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 4, 82, 102, 3 55328       up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 82, 102, 3 128         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 82, 102, 3 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 4, 82, 102, 3 27680       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 82, 102, 3 128         conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 4, 82, 102, 3 2080        up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 82, 102, 3 0           batch_normalization_9[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 82, 102, 3 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 4, 82, 102, 2 1730        activation_9[0][0]
# ==================================================================================================
# Total params: 1,299,330
# Trainable params: 1,298,050
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
# 1. Reconstruction Error:Evaluate how well the autoencoder can reconstruct the input data

from sklearn.metrics import mean_squared_error, mean_absolute_error

decoded_val = autoencoder.predict(X_val)

# Mean Squared Error (MSE)
mse = mean_squared_error(X_val.flatten(), decoded_val.flatten())

# Mean Absolute Error (MAE)
mae = mean_absolute_error(X_val.flatten(), decoded_val.flatten())

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
# Out:
# Mean Squared Error: 0.00011903555899868252
# Mean Absolute Error: 0.007710221525083468

# %%
# Save Summary text file
original_stdout = sys.stdout  # Save a reference to the original standard output

with open('model_summary.txt', 'w') as f:
    sys.stdout = f  # Change the standard output to the file we created.
    print(autoencoder.summary())
    sys.stdout = original_stdout  # Reset the standard output to its original value

# %%
# Save the history object 
import pandas as pd
import pickle

# Convert the history.history dict to a pandas DataFrame
hist_df = pd.DataFrame(history.history)

# Save to csv
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# Save to pickle
with open('history.pkl', 'wb') as file:
    pickle.dump(history.history, file)

# %%
# Load the saved history 

loaded_history = pd.read_csv('history.csv')

with open('history.pkl', 'rb') as file:
    loaded_history = pickle.load(file)

# %%
# Define the encoder model. Find the low dimension layer according to the model summary. 'activation_15' should be the encoder layer
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('activation_5').output)

# %%
encoder_output = autoencoder.get_layer('activation_5').output

# %%
# Save the model
autoencoder.save('autoencoder_yjmodel.h5')
# Out:
# /home/jianhong/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
# Save the weights
autoencoder.save_weights('autoencoder_yjweights.h5')

# %%
# Save whole training database encoded_database
encoded_database = encoder.predict(X_train)

# Save the encoded data as np and h5py

np. save('encoded_database.npy', encoded_database)

import h5py

with h5py.File('encoded_database', 'w') as h5f:
    h5f.create_dataset('dataset_1', data=encoded_database)

# %%
# Load the model
from tensorflow.keras.models import load_model

autoencoder = load_model('autoencoder_yjmodel.h5')

# %%
# Preprocess and Encode the ##Input Day$$ Data, here use 28th Oct 2023 


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()

Oct_28_2023 = nc.Dataset('Oct_28_00UTC.nc')
#Oct_15_2023 = nc.Dataset('/home/jianhong/Desktop/Analogue-Nowcasting-Model (copy)/15_Oct.nc')
z_input = Oct_28_2023['z'][:]
u_input = Oct_28_2023['u'][:]
v_input = Oct_28_2023['v'][:]

# Normalize the data
scaler = MinMaxScaler()
z_input_normalized = scaler.fit_transform(z_input.reshape(-1, 1)).reshape(z_input.shape)
u_input_normalized = scaler.fit_transform(u_input.reshape(-1, 1)).reshape(u_input.shape)
v_input_normalized = scaler.fit_transform(v_input.reshape(-1, 1)).reshape(v_input.shape)


# Combine the parameters to form a single dataset
data_combined = np.stack((z_input_normalized, u_input_normalized , v_input_normalized), axis=-1)
print(data_combined.shape)
np.info(data_combined)


# Pad the data to get even dimensions
input_day_padded = np.pad(data_combined, ((0,0),(0, 1), (0, 1), (0, 1), (0, 0)), mode='constant')


np.info(input_day_padded)
# Use the encoder to generate the encoded representation of this input day’s data
#input_day_encoded = encoder.predict(input_day_padded)
# Out:
# (1, 3, 81, 101, 3)
# class:  ndarray
# shape:  (1, 3, 81, 101, 3)
# strides:  (589032, 196344, 2424, 24, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x562f6841f480
# byteorder:  little
# byteswap:  False
# type: float64
# class:  ndarray
# shape:  (1, 4, 82, 102, 3)
# strides:  (802944, 200736, 2448, 24, 8)
# itemsize:  8
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x562f68820040
# byteorder:  little
# byteswap:  False
# type: float64

# %%
encoded_input = encoder.predict(input_day_padded)
np.info(encoded_input)
# Out:
# class:  ndarray
# shape:  (1, 2, 41, 51, 128)
# strides:  (2141184, 1070592, 26112, 512, 4)
# itemsize:  4
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x55afbb4349d0
# byteorder:  little
# byteswap:  False
# type: float32

# %%
np.info(encoded_database)
# Out:
# class:  ndarray
# shape:  (511, 2, 41, 51, 128)
# strides:  (2141184, 1070592, 26112, 512, 4)
# itemsize:  4
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x7fa211914010
# byteorder:  little
# byteswap:  False
# type: float32

# %%
# Calculate similarities and find the most similar day:

# Use <Euclidean distances> to calculate the Euclidean distances between the input day's encoded representation and the encoded representations of all the days in the database.



input_flattened = encoded_input.reshape(1,-1)
database_flattened = encoded_database.reshape(encoded_database.shape[0], -1)


#np.info(input_flattened)
#np.info(database_flattened)

from sklearn.metrics.pairwise import euclidean_distances
import numpy as np


# Calculate Euclidean distances 
distances = euclidean_distances(input_flattened, database_flattened)



sorted_data= np.argsort(distances)


most_similar_dates = dates_train[sorted_data]
# Calculate Euclidean distances 
#distances = np.array([euclidean(input_flattened,sample) for sample in database_flattened])

#indices_of_smallest = np.argsort(distance)[:3]
most_similar_dates
# Out:
# masked_array(data=[[cftime.DatetimeGregorian(2021, 7, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 8, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 10, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 7, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 6, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 6, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 8, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 9, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 9, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 7, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 10, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 14, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 15, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 4, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 28, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 26, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 5, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 13, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 29, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 3, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 25, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 3, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 2, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 18, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 19, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 7, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 16, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 4, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 27, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 20, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 5, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 11, 10, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 11, 17, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 3, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 22, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 5, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 6, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 12, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 8, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 4, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 1, 9, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 24, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 31, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 11, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 1, 2, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2021, 12, 30, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 21, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 23, 0, 0, 0, 0, has_year_zero=False),
#                     cftime.DatetimeGregorian(2020, 2, 22, 0, 0, 0, 0, has_year_zero=False)]],
#              mask=False,
#        fill_value='?',
#             dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Normalize the data
scaler = MinMaxScaler()

Nov_28_2023 = nc.Dataset('Nov_28_2023.nc')
#Oct_15_2023 = nc.Dataset('/home/jianhong/Desktop/Analogue-Nowcasting-Model (copy)/15_Oct.nc')
#z_input = Nov_28_2023['z'][:]
u_input = Nov_28_2023['u'][:]
v_input = Nov_28_2023['v'][:]

# Normalize the data
scaler = MinMaxScaler()
#z_input_normalized = scaler.fit_transform(z_input.reshape(-1, 1)).reshape(z_input.shape)
u_input_normalized = scaler.fit_transform(u_input.reshape(-1, 1)).reshape(u_input.shape)
v_input_normalized = scaler.fit_transform(v_input.reshape(-1, 1)).reshape(v_input.shape)


# Combine the parameters to form a single dataset
#data_combined = np.stack((z_input_normalized, u_input_normalized , v_input_normalized), axis=-1)
data_combined = np.stack((u_input_normalized , v_input_normalized), axis=-1)
#print(data_combined.shape)
#np.info(data_combined)


# Pad the data to get even dimensions
input_day_padded = np.pad(data_combined, ((0,0),(0, 1), (0, 1), (0, 1), (0, 0)), mode='constant')


#np.info(input_day_padded)
# Use the encoder to generate the encoded representation of this input day’s data
#input_day_encoded = encoder.predict(input_day_padded)

# %%
encoded_input = encoder.predict(input_day_padded)
input_flattened = encoded_input.reshape(1,-1)
database_flattened = encoded_database.reshape(encoded_database.shape[0], -1)


#np.info(input_flattened)
#np.info(database_flattened)

from sklearn.metrics.pairwise import euclidean_distances
import numpy as np


# Calculate Euclidean distances 
distances = euclidean_distances(input_flattened, database_flattened).flatten()

sorted_data= np.argsort(distances)


most_similar_dates = dates_train[sorted_data][:5]

most_similar_dates
# Calculate Euclidean distances 
#distances = np.array([euclidean(input_flattened,sample) for sample in database_flattened])

#indices_of_smallest = np.argsort(distance)[:3]
# Out:
# masked_array(data=[cftime.DatetimeGregorian(2021, 11, 29, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 4, 2, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 12, 6, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 1, 16, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 12, 9, 0, 0, 0, 0, has_year_zero=False)],
#              mask=False,
#        fill_value='?',
#             dtype=object)
